# %% [markdown]
# # With Beautiful Soup & Requests

# %%
import requests
import bs4
import re

source = ['https://www.forbes.com/lists/ai50']

# %%
class Companies:
    
    def __init__(self):
        self.list = []
        self.

# %%
class Company:
    
    def __init__(self,name):
        self.name = name
        self.open_roles = []
        self.departments = set()
        
    def add_open_role(self, role):
        self.open_roles.append(role)
        self.departments.add(role.department)
    
    def __str__(self):
        roles = ''
        for role in self.open_roles:
            roles += f"\n{role.__str__()}"
        
        return f"{self.name.capitalize()} has: {roles}"

# %%
class Role:
    def __init__(self, title, location, link, department):
        self.title = title
        self.location = location
        self.link = link
        self.department = department
        
    def __str__(self):
        return f"{self.title} in {self.location}"

# %%
def init_bs4(base_url):
    result = requests.get(base_url).text
    return bs4.BeautifulSoup(result, "html.parser")

# %%
def scrape_lever(company):
    soup = init_bs4(f"https://jobs.lever.co/{company.name}")
    departments = soup.select('.postings-group')
    
    for department in departments:
        department_name = department.select('.posting-category-title')[0].get_text()
        
        for opening in department.select('.posting'):
            title = opening.find('h5').text
            location = opening.select('.location')[0].get_text()
            link = opening.select('.posting-apply a')[0]['href']

            role = Role(title, location, link, department_name)
            company.add_open_role(role)

def scrape_greenhouse(company):
    soup = init_bs4(f"https://boards.greenhouse.io/{company.name}")
    departments = soup.select('section.level-0')
    
    for department in departments:
        department_name = department.find('h3').text
        
        for opening in department.select('.opening'):
            title = opening.find('a').text
            location = opening.select('.location')[0].get_text()
            link = f"https://boards.greenhouse.io{opening.select('a')[0]['href']}"
            
            role = Role(title, location, link, department_name)
            company.add_open_role(role)

# %%
company_names = ['shieldai', 'quantummetric']
companies = []

for name in company_names:  
    company = Company(name)
    scrape_lever(company)
    print("---")
    print(f"{company.name.capitalize()} : {len(company.open_roles)}")
    print("")
    print(company.departments())
    print("")
    for role in company.open_roles:
        print(role.__str__())
# Out:
# ---
# Shieldai : 40
#
# {'Production Management', 'Hivemind - Hivemind Edge', 'Platform - Systems', 'Production and Supply Chain', 'Design', 'Platform - Mechanical', 'Deployed Operations', 'Fleet Asset Management', 'Platform - Test', 'Hivemind - Hivemind Design', 'Platform - Electrical', 'Hivemind - Test', 'Hivemind - Systems', 'Supply Chain Management', 'Finance', 'Service Operations', 'Technical Directors', 'Program Management', 'Enterprise Operations'}
#
# Accounts Payable Manager (on site in Dallas) in Dallas Metro Area
# Manager, Government Compliance (R2155) in United States
# V-BAT Air Vehicle Operator (R1910) in Dallas Metro Area
# V-BAT Operations Officer (R2142) in Dallas Metro Area
# IT Services Manager in Washington DC Metro Area
# Senior Cybersecurity Manager (R2037) in Dallas Metro Area
# Senior Systems Administrator (R1941) in Washington DC Metro Area
# Fleet Engineer (R1898) in Dallas Metro Area
# Fleet Management Project Manager (R2144) in Dallas Metro Area
# Continuous Improvement Engineer (R2014) in Dallas Metro Area
# Director of Quality in Dallas Metro Area
# Production Supervisor (2nd Shift) (R2184) in Dallas Metro Area
# Inventory Clerk, V-BAT Internal Fleet (R2174) in Dallas Metro Area
# Price/Cost Analyst, Material Estimator, San Diego, CA or Frisco, TX (R2090) in Dallas Metro Area
# Subcontracts Admin, Dallas, TX or San Diego, CA (R2134) in United States
# Subcontracts/Procurement Manager (R2021) in Dallas Metro Area
# Director of User Experience Design (San Diego, Dallas, or Washington DC) (R2137) in United States
# Senior C++ Modeling & Simulation Engineer (R1914) in Washington DC Metro Area
# Software Engineer C++ in California, MD
# Engineering Manager, PAC (R2124) in San Diego Metro Area
# Engineering Manager, PAC (R2124) in Dallas Metro Area
# Software Engineering Manager, Build & Tools (R1659) in San Diego Metro Area
# Software Engineering Manager, Build & Tools (R1659) in Dallas Metro Area
# Staff Engineer in San Diego Metro Area
# Staff Systems Engineer, Dallas (R2083) in Dallas Metro Area
# Staff Systems Engineer, San Diego (R2083) in San Diego Metro Area
# Systems Engineering Manager, Dallas (R2079) in Dallas Metro Area
# Systems Engineering Manager, San Diego (R2079) in San Diego Metro Area
# Staff Software Foundations Test Engineer, Dallas (R2138) in Dallas Metro Area
# Staff Software Foundations Test Engineer, San Diego (R2138) in San Diego Metro Area
# Test Operations Engineering Manager (R2106) in San Diego Metro Area
# Electrical Engineer (2153) in Dallas Metro Area
# Sr Manager of Electrical Engineering, RF (R2151) in Dallas Metro Area
# Staff Electrical Engineer (R1958) in Dallas Metro Area
# Senior Propulsion Engineer (R2180) in Dallas Metro Area
# Staff Propulsion Engineer (R2173) in Dallas Metro Area
# Staff Systems Engineer, Dallas (R2110) in Dallas Metro Area
# Senior Staff Aircraft Systems Test Engineer (R2073) in Dallas Metro Area
# Project Manager/Program Manager Dallas TX (R2187) in Dallas Metro Area
# Technical Director, D.C. (R2020) in Washington DC Metro Area
# ---
# Quantummetric : 9
#
# {'Customer Success Business Consultant', 'Engineering', 'Product', 'Account Management'}
#
# Account Manager - East in United States
# Business Consultant - Central in United States
# Business Consultant - East in United States
# Business Consultant - EMEA (German Speaking) in London, England
# Business Consultant - EMEA (German Speaking) in Madrid
# Business Consultant - West in United States
# Sr. Software Engineer - Android in United States
# Sr. Software Engineer - iOS in United States
# VP of Product Design & Research in United States

# %%
company_names = ['assemblyai', 'openai']
companies = []

for name in company_names:  
    company = Company(name)
    scrape_greenhouse(company)
    print("---")
    print(f"{company.name.capitalize()} : {len(company.open_roles)}")
    print("")
    print(company.departments())
    print("")
    for role in company.open_roles:
        print(role.__str__())
# Out:
# ---
# Assemblyai : 7
#
# {'Engineering', 'Marketing', 'Product'}
#
# Technical Program Manager in Remote
# IT Systems Administrator  in Remote
# Software Engineer in Test (SDET) in Remote
# Software Engineer, Python/Go  in Remote
# Senior Technical Product Marketing Manager in Remote
# Developer Educator - Python/Golang in Remote
# Product Manager in Remote
# ---
# Openai : 44
#
# {'Finance', 'Legal', 'Public Policy', 'Go To Market', 'Communications Design', 'Trust & Safety', 'IT', 'Research, Engineering, Product'}
#
# Full-Stack Developer, Communications & Design in San Francisco, California, United States
# Consolidations Accounting Manager in San Francisco, California, United States
# Head of Procurement in San Francisco, California, United States
# Revenue Accounting Manager in San Francisco, California, United States
# Senior Revenue Accountant, Deal Desk in San Francisco, California, United States
# Account Engineer in San Francisco, California, United States
# IT Application Engineer in San Francisco, California, United States
# Litigation Paralegal in San Francisco, California, United States
# Congressional Lead, Public Policy in Washington, District of Columbia, United States
# Chat Platform Engineer in San Francisco, California, United States
# Manager, Scientist Deployment in San Francisco, California, United States
# AI Alignment - Research Engineer  in San Francisco, California, United States
# Research Engineer in San Francisco, California, United States
# Research Scientist in San Francisco, California, United States
# Applied AI, Engineering Manager- Fraud  in San Francisco, California, United States
# Applied AI, Engineering Manager - Safety in San Francisco, California, United States
# Applied AI, Senior Engineering Manager, Infrastructure in San Francisco, California, United States
# Senior Software Engineer- Identity Platform  in San Francisco, California, United States
# Software Engineer, Billing and Monetization  in San Francisco, California, United States
# Software Engineer, ChatGPT Product Backend in San Francisco, California, United States
# Software Engineer, ChatGPT Product Development in San Francisco, California, United States
# Software Engineer, Fraud in San Francisco, California, United States
# Software Engineer (Full Stack) – API in San Francisco, California, United States
# Software Engineer (Full Stack) – DALL·E in San Francisco, California, United States
# Software Engineer, Model Inference in San Francisco, California, United States
# Software Engineer, Product Development in San Francisco, California, United States
# Software Engineer, Safety in San Francisco, California, United States
# Tech Lead Manager - Identity Platform  in San Francisco, California, United States
# Solutions Engineer, Government and Nonprofit  in San Francisco, California, United States
# Software Engineer (Full Stack), DALL·E  in San Francisco, California, United States
# Policy Research Scientist, Geopolitics  in San Francisco, California, United States
# Research Scientist, Machine Learning in San Francisco, California, United States
# Software Engineer, Front-end/UX in San Francisco, California, United States
# Software Engineer, Backend Infra in San Francisco, California, United States
# Software Engineer, Distributed Model Training in San Francisco, California, United States
# Software Engineer, Triton Compiler in San Francisco, California, United States
# Machine Learning Engineer, Moderation in San Francisco, California, United States
# Research Scientist, Safety in San Francisco, California, United States
# Software Engineer, Hardware Health in San Francisco, California, United States
# Research Engineer, Privacy in San Francisco, California, United States
# Software Engineer, Privacy in San Francisco, California, United States
# Software Engineer, Security in San Francisco, California, United States
# Software Engineer, Infrastructure in San Francisco, California, United States
# Stakeholder Engagement Manager, Product Policy in San Francisco, California, United States

# %% [markdown]
# # With Scrapy

# %%
import scrapy

# %%
# scrape webpage
import scrapy
from scrapy.crawler import CrawlerRunner
# text cleaning
import re
# Reactor restart
from crochet import setup, wait_for
setup()

class QuotesToCsv(scrapy.Spider):
    """scrape first line of  quotes from `wikiquote` by 
    Maynard James Keenan and save to json file"""
    name = "MJKQuotesToCsv"
    start_urls = [
        'https://en.wikiquote.org/wiki/Maynard_James_Keenan',
    ]
    custom_settings = {
        'ITEM_PIPELINES': {
            '__main__.ExtractFirstLine': 1
        },
        'FEEDS': {
            'quotes.csv': {
                'format': 'csv',
                'overwrite': True
            }
        }
    }

    def parse(self, response):
        """parse data from urls"""
        for quote in response.css('div.mw-parser-output > ul > li'):
            yield {'quote': quote.extract()}


class ExtractFirstLine(object):
    def process_item(self, item, spider):
        """text processing"""
        lines = dict(item)["quote"].splitlines()
        first_line = self.__remove_html_tags__(lines[0])

        return {'quote': first_line}

    def __remove_html_tags__(self, text):
        """remove html tags from string"""
        html_tags = re.compile('<.*?>')
        return re.sub(html_tags, '', text)

@wait_for(10)
def run_spider():
    """run spider with MJKQuotesToCsv"""
    crawler = CrawlerRunner()
    d = crawler.crawl(QuotesToCsv)
    return d
